# %%
import duckdb
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# The code analyzes geographic data from Foursquare's Open Street Places dataset, specifically the September 9, 2025 snapshot. It helps understand the available data fields before performing more complex queries or analysis.

# %%
conn = duckdb.connect()


print("Table structure for categories:")
categories_structure = conn.execute("""
DESCRIBE
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/categories/parquet/**/*.parquet')
""").df()
print(categories_structure)

print("\nTable structure for places:")
places_structure = conn.execute("""
DESCRIBE
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet')
""").df()
print(places_structure)

print("\nSample categories:")
sample_categories = conn.execute("""
SELECT *
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/categories/parquet/**/*.parquet')
LIMIT 10
""").df()
print(sample_categories)
# Out:
# Table structure for categories:
#              column_name column_type null   key default extra
# 0            category_id     VARCHAR  YES  None    None  None
# 1         category_level     INTEGER  YES  None    None  None
# 2          category_name     VARCHAR  YES  None    None  None
# 3         category_label     VARCHAR  YES  None    None  None
# 4     level1_category_id     VARCHAR  YES  None    None  None
# 5   level1_category_name     VARCHAR  YES  None    None  None
# 6     level2_category_id     VARCHAR  YES  None    None  None
# 7   level2_category_name     VARCHAR  YES  None    None  None
# 8     level3_category_id     VARCHAR  YES  None    None  None
# 9   level3_category_name     VARCHAR  YES  None    None  None
# 10    level4_category_id     VARCHAR  YES  None    None  None
# 11  level4_category_name     VARCHAR  YES  None    None  None
# 12    level5_category_id     VARCHAR  YES  None    None  None
# 13  level5_category_name     VARCHAR  YES  None    None  None
# 14    level6_category_id     VARCHAR  YES  None    None  None
# 15  level6_category_name     VARCHAR  YES  None    None  None
# 16                    dt        DATE  YES  None    None  None
#
# Table structure for places:
#             column_name                                        column_type  \
# 0          fsq_place_id                                            VARCHAR
# 1                  name                                            VARCHAR
# 2              latitude                                             DOUBLE
# 3             longitude                                             DOUBLE
# 4               address                                            VARCHAR
# 5              locality                                            VARCHAR
# 6                region                                            VARCHAR
# 7              postcode                                            VARCHAR
# 8          admin_region                                            VARCHAR
# 9             post_town                                            VARCHAR
# 10               po_box                                            VARCHAR
# 11              country                                            VARCHAR
# 12         date_created                                            VARCHAR
# 13       date_refreshed                                            VARCHAR
# 14          date_closed                                            VARCHAR
# 15                  tel                                            VARCHAR
# 16              website                                            VARCHAR
# 17                email                                            VARCHAR
# 18          facebook_id                                             BIGINT
# 19            instagram                                            VARCHAR
# 20              twitter                                            VARCHAR
# 21     fsq_category_ids                                          VARCHAR[]
# 22  fsq_category_labels                                          VARCHAR[]
# 23       placemaker_url                                            VARCHAR
# 24     unresolved_flags                                          VARCHAR[]
# 25                 geom                                               BLOB
# 26                 bbox  STRUCT(xmin DOUBLE, ymin DOUBLE, xmax DOUBLE, ...
# 27                   dt                                               DATE
#
#    null   key default extra
# 0   YES  None    None  None
# 1   YES  None    None  None
# 2   YES  None    None  None
# 3   YES  None    None  None
# 4   YES  None    None  None
# 5   YES  None    None  None
# 6   YES  None    None  None
# 7   YES  None    None  None
# 8   YES  None    None  None
# 9   YES  None    None  None
# 10  YES  None    None  None
# 11  YES  None    None  None
# 12  YES  None    None  None
# 13  YES  None    None  None
# 14  YES  None    None  None
# 15  YES  None    None  None
# 16  YES  None    None  None
# 17  YES  None    None  None
# 18  YES  None    None  None
# 19  YES  None    None  None
# 20  YES  None    None  None
# 21  YES  None    None  None
# 22  YES  None    None  None
# 23  YES  None    None  None
# 24  YES  None    None  None
# 25  YES  None    None  None
# 26  YES  None    None  None
# 27  YES  None    None  None
#
# Sample categories:
#                 category_id  category_level          category_name  \
# 0  63be6904847c3692a84b9ba8               2       Homeless Shelter
# 1  52939aed3cf9994f4e043a3c               6     Mineiro Restaurant
# 2  53d6c1b0e4b02351e88a83de               4    Tsipouro Restaurant
# 3  4bf58dd8d48988d1e4941735               2             Campground
# 4  63be6904847c3692a84b9bcc               3     Gastroenterologist
# 5  4bf58dd8d48988d14e941735               3    American Restaurant
# 6  4bf58dd8d48988d199941735               4  College Arts Building
# 7  4eb1c0253b7b52c0e1adc2e9               2          Garden Center
# 8  63be6904847c3692a84b9bbd               3      Ambulance Service
# 9  4bf58dd8d48988d16d941735               3                   Café
#
#                                       category_label  \
# 0        Community and Government > Homeless Shelter
# 1  Dining and Drinking > Restaurant > Latin Ameri...
# 2  Dining and Drinking > Restaurant > Greek Resta...
# 3                Landmarks and Outdoors > Campground
# 4  Health and Medicine > Physician > Gastroentero...
# 5  Dining and Drinking > Restaurant > American Re...
# 6  Community and Government > Education > College...
# 7                             Retail > Garden Center
# 8  Health and Medicine > Emergency Service > Ambu...
# 9  Dining and Drinking > Cafe, Coffee, and Tea Ho...
#
#          level1_category_id      level1_category_name  \
# 0  63be6904847c3692a84b9b9a  Community and Government
# 1  63be6904847c3692a84b9bb5       Dining and Drinking
# 2  63be6904847c3692a84b9bb5       Dining and Drinking
# 3  4d4b7105d754a06377d81259    Landmarks and Outdoors
# 4  63be6904847c3692a84b9bb9       Health and Medicine
# 5  63be6904847c3692a84b9bb5       Dining and Drinking
# 6  63be6904847c3692a84b9b9a  Community and Government
# 7  4d4b7105d754a06378d81259                    Retail
# 8  63be6904847c3692a84b9bb9       Health and Medicine
# 9  63be6904847c3692a84b9bb5       Dining and Drinking
#
#          level2_category_id         level2_category_name  \
# 0  63be6904847c3692a84b9ba8             Homeless Shelter
# 1  4d4b7105d754a06374d81259                   Restaurant
# 2  4d4b7105d754a06374d81259                   Restaurant
# 3  4bf58dd8d48988d1e4941735                   Campground
# 4  63be6904847c3692a84b9bc6                    Physician
# 5  4d4b7105d754a06374d81259                   Restaurant
# 6  4bf58dd8d48988d13b941735                    Education
# 7  4eb1c0253b7b52c0e1adc2e9                Garden Center
# 8  63be6904847c3692a84b9bbc            Emergency Service
# 9  63be6904847c3692a84b9bb6  Cafe, Coffee, and Tea House
#
#          level3_category_id       level3_category_name  \
# 0                      None                       None
# 1  4bf58dd8d48988d1be941735  Latin American Restaurant
# 2  4bf58dd8d48988d10e941735           Greek Restaurant
# 3                      None                       None
# 4  63be6904847c3692a84b9bcc         Gastroenterologist
# 5  4bf58dd8d48988d14e941735        American Restaurant
# 6  4d4b7105d754a06372d81259     College and University
# 7                      None                       None
# 8  63be6904847c3692a84b9bbd          Ambulance Service
# 9  4bf58dd8d48988d16d941735                       Café
#
#          level4_category_id       level4_category_name  \
# 0                      None                       None
# 1  4bf58dd8d48988d1cd941735  South American Restaurant
# 2  53d6c1b0e4b02351e88a83de        Tsipouro Restaurant
# 3                      None                       None
# 4                      None                       None
# 5                      None                       None
# 6  4bf58dd8d48988d199941735      College Arts Building
# 7                      None                       None
# 8                      None                       None
# 9                      None                       None
#
#          level5_category_id  level5_category_name        level6_category_id  \
# 0                      None                  None                      None
# 1  4bf58dd8d48988d16b941735  Brazilian Restaurant  52939aed3cf9994f4e043a3c
# 2                      None                  None                      None
# 3                      None                  None                      None
# 4                      None                  None                      None
# 5                      None                  None                      None
# 6                      None                  None                      None
# 7                      None                  None                      None
# 8                      None                  None                      None
# 9                      None                  None                      None
#
#   level6_category_name         dt
# 0                 None 2025-09-09
# 1   Mineiro Restaurant 2025-09-09
# 2                 None 2025-09-09
# 3                 None 2025-09-09
# 4                 None 2025-09-09
# 5                 None 2025-09-09
# 6                 None 2025-09-09
# 7                 None 2025-09-09
# 8                 None 2025-09-09
# 9                 None 2025-09-09

# %% [markdown]
# Identifying relevant categories like restaurants, bars, and cafes, then match them with actual places in Moscow

# %%
query = """
WITH target_categories AS (
    SELECT
        category_id,
        category_name,
        level1_category_name
    FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/categories/parquet/**/*.parquet')
    WHERE
        level1_category_name = 'Dining and Drinking'
        OR category_name ILIKE '%restaurant%'
        OR category_name ILIKE '%bar%'
        OR category_name ILIKE '%cafe%'
        OR category_name ILIKE '%coffee%'
        OR category_name ILIKE '%pub%'
        OR category_name ILIKE '%bistro%'
)
SELECT DISTINCT
    p.fsq_place_id,
    p.name,
    p.latitude,
    p.longitude,
    p.address,
    p.locality,
    p.region,
    p.fsq_category_labels,
    STRING_AGG(DISTINCT c.category_name, ', ') AS matched_categories
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet') p
JOIN target_categories c ON ARRAY_CONTAINS(p.fsq_category_ids, c.category_id)
WHERE
    p.locality = 'Moscow'
    OR p.region = 'Moscow'
    OR p.admin_region = 'Moscow'
GROUP BY ALL
"""

df_result = conn.execute(query).df()
print(f"Found {len(df_result)} establishments in Moscow")

if len(df_result) > 0:
    print("\nDistribution by categories:")
    print(df_result['matched_categories'].value_counts().head(15))

# %% [markdown]
# Scoring each establishment based on category importance and contact information availability, then select the top 500 venues with balanced representation across different types. Finally, I saved the curated dataset for further analysis.

# %%
query = """
SELECT
    fsq_place_id,
    name,
    latitude,
    longitude,
    address,
    locality,
    region,
    tel,
    website,
    instagram,
    fsq_category_labels
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet')
WHERE locality = 'Moscow' OR region = 'Moscow'
LIMIT 1000
"""

df_all = conn.execute(query).df()
print(f"Retrieved establishments for analysis: {len(df_all)}")

print("Category analysis:")
for i in range(min(10, len(df_all))):
    categories = df_all.iloc[i]['fsq_category_labels']
    print(f"{i+1}. {df_all.iloc[i]['name']}: {categories}")

has_categories = df_all['fsq_category_labels'].notna().sum()
print(f"Establishments with categories: {has_categories} out of {len(df_all)}")

query_all = """
SELECT
    fsq_place_id,
    name,
    latitude,
    longitude,
    address,
    locality,
    region,
    tel,
    website,
    instagram,
    fsq_category_labels
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet')
WHERE locality = 'Moscow' OR region = 'Moscow'
"""

df = conn.execute(query_all).df()
print(f"Total establishments in Moscow: {len(df)}")

def safe_categories(categories):
    if categories is None:
        return []
    try:
        return [str(cat) for cat in categories]
    except:
        return []

df['categories_list'] = df['fsq_category_labels'].apply(safe_categories)

def is_food_establishment(categories_list):
    if not categories_list:
        return False

    food_keywords = ['restaurant', 'bar', 'cafe', 'coffee', 'pub', 'bakery', 'steakhouse',
                     'eatery', 'bistro', 'grill', 'pizzeria', 'food', 'dining']

    categories_str = ' '.join(categories_list).lower()
    return any(keyword in categories_str for keyword in food_keywords)

df_food = df[df['categories_list'].apply(is_food_establishment)]
print(f"Food establishments: {len(df_food)}")

if len(df_food) > 0:
    def calculate_score(row):
        score = 0
        categories = row['categories_list']

        for category in categories:
            cat_lower = category.lower()
            if 'restaurant' in cat_lower:
                score += 10
            elif 'steakhouse' in cat_lower:
                score += 9
            elif 'bar' in cat_lower:
                score += 7
            elif 'coffee' in cat_lower or 'cafe' in cat_lower:
                score += 5

        if pd.notna(row['website']) and row['website']:
            score += 3
        if pd.notna(row['tel']) and row['tel']:
            score += 2
        if pd.notna(row['instagram']) and row['instagram']:
            score += 2

        return score

    def categorize(row):
        categories = row['categories_list']
        for category in categories:
            cat_lower = category.lower()
            if 'restaurant' in cat_lower:
                return 'Restaurant'
            if 'bar' in cat_lower:
                return 'Bar'
            if 'coffee' in cat_lower or 'cafe' in cat_lower:
                return 'Coffee'
        return 'Other'

    df_food['score'] = df_food.apply(calculate_score, axis=1)
    df_food['type'] = df_food.apply(categorize, axis=1)

    def select_top_500(df):
        target_counts = {'Restaurant': 200, 'Bar': 150, 'Coffee': 150}
        selected_dfs = []

        for establishment_type, count in target_counts.items():
            type_df = df[df['type'] == establishment_type]
            if len(type_df) > count:
                selected_dfs.append(type_df.nlargest(count, 'score'))
            else:
                selected_dfs.append(type_df)

        result = pd.concat(selected_dfs, ignore_index=True)

        if len(result) > 500:
            result = result.nlargest(500, 'score')

        return result

    df_top_500 = select_top_500(df_food)
    print(f"Selected top 500 establishments: {len(df_top_500)}")
    print("Distribution by type:")
    print(df_top_500['type'].value_counts())

    df_top_500[['fsq_place_id', 'name', 'address', 'latitude', 'longitude',
                'tel', 'website', 'instagram', 'type', 'score']].to_csv(
        'moscow_top_500_with_scoring.csv', index=False, encoding='utf-8')

    print("Dataset with scoring saved")
else:
    print("No food establishments found. Saving all establishments for analysis.")
    df.to_csv('moscow_all_places.csv', index=False, encoding='utf-8')
    print("All establishments saved to moscow_all_places.csv for analysis")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Retrieved establishments for analysis: 1000
# Category analysis:
# 1. 👾 Digital Fest 2017 by 🐲Codabra: <NA>
# 2. Good's House: <NA>
# 3. Go! Coffee: <NA>
# 4. House of the princess👸🏼: <NA>
# 5. Детская Площадка Proludia: <NA>
# 6. Heidrick & Struggles: <NA>
# 7. True Burgers: <NA>
# 8. Овощи-фрукты: <NA>
# 9. Продукты 24: <NA>
# 10. Проект-Нейрон: <NA>
# Establishments with categories: 896 out of 1000
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Total establishments in Moscow: 60964
# Food establishments: 12762
# Selected top 500 establishments: 500
# Distribution by type:
# type
# Restaurant    200
# Bar           150
# Coffee        150
# Name: count, dtype: int64
# Dataset with scoring saved
# /tmp/ipython-input-1665747288.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['score'] = df_food.apply(calculate_score, axis=1)
# /tmp/ipython-input-1665747288.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['type'] = df_food.apply(categorize, axis=1)

# %%
df_result = pd.read_csv('moscow_top_500_with_scoring.csv', encoding='utf-8')

print("First 10 establishments:")
print(df_result.head(20))

print("\nBasic data information:")
print(df_result.info())

print("\nDistribution by establishment types:")
print(df_result['type'].value_counts())

print("\nScoring statistics:")
print(df_result['score'].describe())
# Out:
# First 10 establishments:
#                 fsq_place_id                name  \
# 0   58d2918fa37d72231a3d2902   Ресторан Мегрелия
# 1   5abd566fcd441c726ebba02e          Додо пицца
# 2   66b23b9184178a3c525fcb3b         Панда Пицца
# 3   54c69143498ec9064563eee3              Навоке
# 4   5e5bb43dfd0227000789cfaf             Депо #1
# 5   60996b5189850158e4363df0           Мясо’roob
# 6   539ecb90498e35589f8b2326               MrWok
# 7   4e3920cf18a8d2fcc627f5a2      Гейша / Gejsha
# 8   4c877b3a47cc224bc154b19f             El Faro
# 9   52f33fa8498e1496b7d54db6           Wok House
# 10  558fdf2c498e55f78a1c39f8        Terra & Mare
# 11  532c2a89498e91fc7e611da2            Марукамэ
# 12  58122b3138fac81d55eae370     Кафе Хинкальная
# 13  528b469b498e1f5e0763d8a9              YamKee
# 14  4d973c6ddaec224bf4752a3e                 KFC
# 15  4b7c42c2f964a5200e882fe3             Quiznos
# 16  5b8d94704c954c002c9a9ac1      Sonic Drive-In
# 17  4b4945dbf964a5200f6c26e3  WINGERS Restaurant
# 18  54b565e2498e268f6806bbe2        Jimmy John's
# 19  5b41f7b0c0f163002c77b2e8           Neгодники
#
#                                               address   latitude   longitude  \
# 0                      улица Большие Каменщики, дом 1  55.739783   37.654022
# 1                                  Железнодорожая, 51  55.499650   37.570264
# 2                                   ул. Шумкина, 20с1  55.787332   37.670724
# 3                                        ТРЦ «Филион»  55.744006   37.506625
# 4                                   Хорошёвское ш. 27  55.777699   37.523428
# 5                        Черняховского 17А (2-й этаж)  55.807714   37.539593
# 6                           Сущевская ул., 19, стр. 4  55.781813   37.600751
# 7                      Новослободская ул., 31, стр. 1  55.781931   37.597682
# 8                                 ул. Петровка, д. 16  55.763628   37.617552
# 9                             ул. Покровка, 4, стр. 1  55.758690   37.640486
# 10                                 Цветной бул., 20/1  55.770625   37.622332
# 11                              Авиамоторная ул., 41Б  55.753251   37.716522
# 12                           пл. Киевского Вокзала, 2  55.744726   37.567979
# 13                           пл. Киевского Вокзала, 2  55.744110   37.567079
# 14  ул. Мичуринский Проспект, Олимпийская Деревня,...  55.678150   37.466668
# 15                                1902 S. Pullman Dr.  46.733931 -117.027884
# 16                                      433 N Main St  46.738400 -117.001936
# 17                                   1484 S Blaine St  46.721190 -116.985449
# 18                                   529 S Jackson St  46.730217 -117.002990
# 19                               ул. Спиридоновка, 26  55.762319   37.591709
#
#                   tel                                            website  \
# 0   8 (495) 915-62-38                                 http://megrelia.ru
# 1   8 (800) 302-00-60                        http://dodopizza.onelink.me
# 2   8 (800) 777-72-00                             https://panda-pizza.ru
# 3   8 (495) 737-59-56                                   http://nawoke.ru
# 4   8 (925) 421-59-65                                http://depo-rest.ru
# 5   8 (800) 500-83-93                            http://msk.myasoroob.ru
# 6   8 (495) 789-49-50                                    http://mrwok.ru
# 7   8 (495) 514-84-66               http://www.gejsha.ru/restaurant.html
# 8   8 (495) 626-44-80                         http://www.elfaro-cafe.ru/
# 9   8 (495) 643-13-30                                http://wok-house.ru
# 10  8 (495) 608-15-19                          http://www.terra-marre.ru
# 11  8 (495) 580-75-50                                 http://marukame.ru
# 12  8 (495) 721-90-51                          http://kafekhinkalnaya.ru
# 13  8 (800) 775-61-50                                  http://yamkee.com
# 14  8 (495) 641-24-42                                  http://www.kfc.ru
# 15     (208) 882-8800                                 http://quiznos.com
# 16     (208) 883-9800  https://locations.sonicdrivein.com/id/moscow/4...
# 17     (208) 882-9850                              http://wingerbros.com
# 18     (208) 883-3278  https://locations.jimmyjohns.com/id/moscow/san...
# 19  8 (985) 190-88-88                                                NaN
#
#         instagram        type  score
# 0   megrelia_rest  Restaurant     37
# 1             NaN  Restaurant     35
# 2             NaN  Restaurant     35
# 3             NaN  Restaurant     35
# 4             NaN  Restaurant     35
# 5             NaN  Restaurant     35
# 6             NaN  Restaurant     35
# 7             NaN  Restaurant     35
# 8             NaN  Restaurant     35
# 9             NaN  Restaurant     35
# 10            NaN  Restaurant     35
# 11            NaN  Restaurant     35
# 12            NaN  Restaurant     35
# 13            NaN  Restaurant     35
# 14            NaN  Restaurant     35
# 15            NaN  Restaurant     35
# 16            NaN  Restaurant     35
# 17            NaN  Restaurant     35
# 18            NaN  Restaurant     35
# 19  st_negodniki_  Restaurant     34
#
# Basic data information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fsq_place_id  500 non-null    object
#  1   name          500 non-null    object
#  2   address       435 non-null    object
#  3   latitude      500 non-null    float64
#  4   longitude     500 non-null    float64
#  5   tel           333 non-null    object
#  6   website       290 non-null    object
#  7   instagram     103 non-null    object
#  8   type          500 non-null    object
#  9   score         500 non-null    int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 39.2+ KB
# None
#
# Distribution by establishment types:
# type
# Restaurant    200
# Bar           150
# Coffee        150
# Name: count, dtype: int64
#
# Scoring statistics:
# count    500.000000
# mean      22.298000
# std        6.040378
# min       13.000000
# 25%       17.000000
# 50%       22.000000
# 75%       27.000000
# max       37.000000
# Name: score, dtype: float64

# %% [markdown]
# Filtering out fast food chains and low-quality venues while identifying premium dining establishments like restaurants, bars, and cafes. I score each venue based on category quality and contact information, then select the top 500 quality establishments with balanced representation across different types.

# %%
query = """
SELECT
    fsq_place_id,
    name,
    latitude,
    longitude,
    address,
    locality,
    region,
    tel,
    website,
    instagram,
    fsq_category_labels
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet')
WHERE locality = 'Moscow' OR region = 'Moscow'
"""

df = conn.execute(query).df()
print(f"Total establishments in Moscow: {len(df)}")

def safe_categories(categories):
    if categories is None:
        return []
    try:
        return [str(cat) for cat in categories]
    except:
        return []

df['categories_list'] = df['fsq_category_labels'].apply(safe_categories)

fast_food_chains = [
    'додо пицца', 'dodo pizza', 'kfc', 'макдональд', 'mcdonald', 'бургер кинг',
    'burger king', 'субвей', 'subway', 'панда пицца', 'panda pizza', 'тарту',
    'тартуга', 'вкусно и точка', 'чикен', 'chicken', 'шаурма', 'шаверма'
]

low_quality_keywords = [
    'столовая', 'кафетерий', 'фудкорт', 'food court', 'фастфуд', 'fast food',
    'сетевое', 'сеть', 'chain'
]

def is_quality_food_establishment(row):
    """Checks if establishment is quality (not fast food)"""
    categories = row['categories_list']
    name = str(row['name']).lower()

    for chain in fast_food_chains:
        if chain in name:
            return False

    for keyword in low_quality_keywords:
        if keyword in name:
            return False

    if not categories:
        return False

    categories_str = ' '.join(categories).lower()

    fast_food_categories = ['fast food', 'food court', 'cafeteria']
    for cat in fast_food_categories:
        if cat in categories_str:
            return False

    quality_keywords = [
        'restaurant', 'bar', 'cafe', 'coffee', 'pub', 'steakhouse',
        'eatery', 'bistro', 'grill', 'wine bar', 'cocktail bar',
        'итальянск', 'французск', 'японск', 'европейск', 'авторск'
    ]

    return any(keyword in categories_str for keyword in quality_keywords)

df_quality = df[df.apply(is_quality_food_establishment, axis=1)]
print(f"Quality establishments: {len(df_quality)}")

def calculate_quality_score(row):
    score = 0
    categories = row['categories_list']
    name = str(row['name']).lower()

    premium_keywords = {
        'restaurant': 15,
        'steakhouse': 14,
        'bistro': 13,
        'grill': 12,
        'bar': 10,
        'wine bar': 12,
        'cocktail bar': 11,
        'pub': 8,
        'cafe': 7,
        'coffee': 6
    }

    if categories:
        categories_str = ' '.join(categories).lower()
        for keyword, points in premium_keywords.items():
            if keyword in categories_str:
                score += points
                break

    if pd.notna(row['website']) and row['website']:
        score += 5
    if pd.notna(row['tel']) and row['tel']:
        score += 3
    if pd.notna(row['instagram']) and row['instagram']:
        score += 4

    score += 10

    chain_indicators = ['#1', '#2', 'филиал', 'сеть']
    for indicator in chain_indicators:
        if indicator in name:
            score -= 5

    return score

def categorize_quality(row):
    categories = row['categories_list']
    if not categories:
        return 'Other'

    categories_str = ' '.join(categories).lower()

    if 'restaurant' in categories_str or 'steakhouse' in categories_str:
        return 'Restaurant'
    elif 'bar' in categories_str or 'pub' in categories_str:
        return 'Bar'
    elif 'cafe' in categories_str or 'coffee' in categories_str:
        return 'Coffee'
    return 'Other'

df_quality['score'] = df_quality.apply(calculate_quality_score, axis=1)
df_quality['type'] = df_quality.apply(categorize_quality, axis=1)

def select_quality_top_500(df):
    target_counts = {'Restaurant': 200, 'Bar': 150, 'Coffee': 150}
    selected_dfs = []

    for establishment_type, count in target_counts.items():
        type_df = df[df['type'] == establishment_type]
        if len(type_df) > count:
            selected_dfs.append(type_df.nlargest(count, 'score'))
        else:
            selected_dfs.append(type_df)

    result = pd.concat(selected_dfs, ignore_index=True)

    if len(result) > 500:
        result = result.nlargest(500, 'score')

    return result

df_top_quality = select_quality_top_500(df_quality)
print(f"Selected quality establishments: {len(df_top_quality)}")
print("Distribution by types:")
print(df_top_quality['type'].value_counts())

print("\nCheck - examples of selected establishments:")
sample_names = df_top_quality['name'].head(20).tolist()
for name in sample_names:
    print(f"  - {name}")

df_top_quality[['fsq_place_id', 'name', 'address', 'latitude', 'longitude',
                'tel', 'website', 'instagram', 'type', 'score']].to_csv(
    'moscow_quality_top_500.csv', index=False, encoding='utf-8')

print("\nQuality dataset saved as moscow_quality_top_500.csv")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Total establishments in Moscow: 60964
# Quality establishments: 8905
# Selected quality establishments: 500
# Distribution by types:
# type
# Restaurant    200
# Bar           150
# Coffee        150
# Name: count, dtype: int64
#
# Check - examples of selected establishments:
#   - Зафрэ
#   - MasterBurgers, бургерная
#   - Мясо&Рыба
#   - Сахара
#   - Ресторан Пивзавод Brotundbeer
#   - Wingstop
#   - Шашлычный Двор № 1
#   - Джонджоли
#   - Грузинские каникулы
#   - Слайс пицца
#   - Гамбринус
#   - Неуловимый Джо
#   - Bear Burgers
#   - Дядюшка Хо
#   - Две палочки
#   - G&T Gourmet
#   - Просто Вкусно Пироги
#   - Domino's Pizza
#   - Melt Me
#   - Вареничная № 1
#
# Quality dataset saved as moscow_quality_top_500.csv
# /tmp/ipython-input-3539029790.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_quality['score'] = df_quality.apply(calculate_quality_score, axis=1)
# /tmp/ipython-input-3539029790.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_quality['type'] = df_quality.apply(categorize_quality, axis=1)

# %% [markdown]
# Dividing Moscow into geographic areas to ensure balanced spatial distribution.Using enhanced K-means clustering with 50 geographic areas, I ensure comprehensive spatial coverage across the city. I score each establishment with an improved algorithm that rewards premium categories, unique concepts, and contact information while penalizing chain operations. The final selection maintains perfect balance across restaurants, bars, and cafes with controlled geographic distribution, providing detailed statistics on scoring, contact availability, and spatial coverage for comprehensive analysis.

# %%
conn = duckdb.connect()

query = """
SELECT
    fsq_place_id,
    name,
    latitude,
    longitude,
    address,
    locality,
    region,
    tel,
    website,
    instagram,
    fsq_category_labels
FROM read_parquet('s3://fsq-os-places-us-east-1/release/dt=2025-09-09/places/parquet/**/*.parquet')
WHERE locality = 'Moscow' OR region = 'Moscow'
"""

df = conn.execute(query).df()
print(f"Total establishments in Moscow: {len(df)}")

def safe_categories(categories):
    if categories is None:
        return []
    try:
        return [str(cat) for cat in categories]
    except:
        return []

df['categories_list'] = df['fsq_category_labels'].apply(safe_categories)

fast_food_chains = [
    'додо пицца', 'dodo pizza', 'kfc', 'макдональд', 'mcdonald', 'бургер кинг',
    'burger king', 'субвей', 'subway', 'панда пицца', 'panda pizza', 'тарту',
    'тартуга', 'вкусно и точка', 'чикен', 'chicken', 'шаурма', 'шаверма',
    'макдоналдс', 'бургер', 'burger', 'пицца', 'pizza', 'суши', 'sushi',
    'му-му', 'муму', 'moo moo', 'столовая', 'кафетерий', 'фудкорт', 'food court',
    'макдоналдс', 'макдак', 'макдач', 'mcDonald', 'kfc', 'kentucky'
]

def is_quality_food_establishment(row):
    categories = row['categories_list']
    name = str(row['name']).lower()

    for chain in fast_food_chains:
        if chain in name:
            return False

    if not categories:
        return False

    categories_str = ' '.join(categories).lower()

    fast_food_categories = ['fast food', 'food court', 'cafeteria']
    for cat in fast_food_categories:
        if cat in categories_str:
            return False

    quality_keywords = [
        'restaurant', 'bar', 'cafe', 'coffee', 'pub', 'steakhouse',
        'eatery', 'bistro', 'grill', 'wine bar', 'cocktail bar',
        'итальянск', 'французск', 'японск', 'европейск', 'авторск',
        'гастропаб', 'паб', 'винный', 'кофейн', 'кондитерск', 'гастроном'
    ]

    return any(keyword in categories_str for keyword in quality_keywords)

df_quality = df[df.apply(is_quality_food_establishment, axis=1)].copy()
print(f"Quality establishments: {len(df_quality)}")

def assign_geo_clusters_improved(df, n_clusters=50):
    coords = df[['latitude', 'longitude']].values
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    df_copy = df.copy()
    df_copy['geo_cluster'] = kmeans.fit_predict(coords)
    return df_copy, kmeans

df_quality, kmeans = assign_geo_clusters_improved(df_quality, n_clusters=50)
print(f"Created geographic clusters: {df_quality['geo_cluster'].nunique()}")

def calculate_enhanced_score(row):
    score = 0
    categories = row['categories_list']
    name = str(row['name']).lower()

    premium_keywords = {
        'restaurant': 15, 'steakhouse': 18, 'bistro': 16, 'grill': 14,
        'bar': 12, 'wine bar': 17, 'cocktail bar': 16, 'pub': 10,
        'cafe': 8, 'coffee': 7, 'гастропаб': 19, 'авторск': 20
    }

    if categories:
        categories_str = ' '.join(categories).lower()
        for keyword, points in premium_keywords.items():
            if keyword in categories_str:
                score += points
                break

    contact_score = 0
    if pd.notna(row['website']) and row['website']:
        contact_score += 8
    if pd.notna(row['tel']) and row['tel']:
        contact_score += 5
    if pd.notna(row['instagram']) and row['instagram']:
        contact_score += 6

    score += contact_score

    unique_indicators = ['авторск', 'гастропаб', 'винный', 'крафтов', 'craft', 'гастроном', 'уникальн']
    premium_indicators = ['премиум', 'premium', 'люкс', 'luxury', 'высок', 'gourmet']

    for indicator in unique_indicators:
        if indicator in name:
            score += 8

    for indicator in premium_indicators:
        if indicator in name:
            score += 10

    chain_penalties = ['сеть', 'chain', 'филиал', '№1', '№2', '№3']
    for penalty in chain_penalties:
        if penalty in name:
            score -= 5

    return score

def categorize_quality(row):
    categories = row['categories_list']
    if not categories:
        return 'Other'

    categories_str = ' '.join(categories).lower()

    if 'restaurant' in categories_str or 'steakhouse' in categories_str or 'bistro' in categories_str:
        return 'Restaurant'
    elif 'bar' in categories_str or 'pub' in categories_str or 'wine bar' in categories_str:
        return 'Bar'
    elif 'cafe' in categories_str or 'coffee' in categories_str:
        return 'Coffee'
    return 'Other'

df_quality['score'] = df_quality.apply(calculate_enhanced_score, axis=1)
df_quality['type'] = df_quality.apply(categorize_quality, axis=1)

def select_1500_balanced(df, total_target=1500):
    target_counts = {'Restaurant': 500, 'Bar': 500, 'Coffee': 500}
    max_per_cluster = {'Restaurant': 25, 'Bar': 20, 'Coffee': 15}

    selected_indices = []

    for establishment_type, type_target in target_counts.items():
        type_df = df[df['type'] == establishment_type].copy()

        if len(type_df) == 0:
            continue

        type_df = type_df.sort_values('score', ascending=False)
        cluster_counts = {}

        for idx, row in type_df.iterrows():
            if len([i for i in selected_indices if df.loc[i, 'type'] == establishment_type]) >= type_target:
                continue

            cluster = row['geo_cluster']

            if cluster not in cluster_counts:
                cluster_counts[cluster] = 0

            if cluster_counts[cluster] < max_per_cluster[establishment_type]:
                selected_indices.append(idx)
                cluster_counts[cluster] += 1

    result = df.loc[selected_indices].copy()

    final_result = []
    type_counts = {'Restaurant': 0, 'Bar': 0, 'Coffee': 0}

    for idx in selected_indices:
        row_type = df.loc[idx, 'type']
        if type_counts[row_type] < target_counts[row_type]:
            final_result.append(idx)
            type_counts[row_type] += 1

    result = df.loc[final_result].copy()

    return result

df_top_1500 = select_1500_balanced(df_quality)
print(f"Selected balanced establishments: {len(df_top_1500)}")
print("Distribution by types:")
print(df_top_1500['type'].value_counts())

print("\nGeographic distribution (top-15 clusters):")
cluster_distribution = df_top_1500['geo_cluster'].value_counts()
print(cluster_distribution.head(15))

print(f"\nTotal clusters represented: {df_top_1500['geo_cluster'].nunique()}")
print(f"Maximum establishments in one cluster: {cluster_distribution.max()}")
print(f"Minimum establishments in one cluster: {cluster_distribution.min()}")

print("\nScoring statistics:")
print(f"Average score: {df_top_1500['score'].mean():.2f}")
print(f"Maximum score: {df_top_1500['score'].max()}")
print(f"Minimum score: {df_top_1500['score'].min()}")

print("\nAverage scoring by type:")
print(df_top_1500.groupby('type')['score'].mean())

print("\nContact information in selected establishments:")
print(f"Websites: {df_top_1500['website'].notna().sum()} ({df_top_1500['website'].notna().sum()/len(df_top_1500)*100:.1f}%)")
print(f"Phones: {df_top_1500['tel'].notna().sum()} ({df_top_1500['tel'].notna().sum()/len(df_top_1500)*100:.1f}%)")
print(f"Instagram: {df_top_1500['instagram'].notna().sum()} ({df_top_1500['instagram'].notna().sum()/len(df_top_1500)*100:.1f}%)")

print("\nTop-15 establishments by score:")
top_15 = df_top_1500.nlargest(15, 'score')[['name', 'type', 'score']]
for i, (_, row) in enumerate(top_15.iterrows(), 1):
    print(f"  {i}. {row['name']} ({row['type']}) - {row['score']} points")

df_top_1500[['fsq_place_id', 'name', 'address', 'latitude', 'longitude',
             'tel', 'website', 'instagram', 'type', 'score', 'geo_cluster']].to_csv(
    'moscow_quality_1500_enhanced.csv', index=False, encoding='utf-8')

cluster_centers = pd.DataFrame(kmeans.cluster_centers_, columns=['latitude', 'longitude'])
cluster_centers['geo_cluster'] = cluster_centers.index
cluster_centers.to_csv('moscow_geo_clusters_50.csv', index=False)

print(f"\nDataset of 1500 establishments saved")
print(f"Information about 50 geographic clusters saved")
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/criptyn97/poi_recommender_/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
restaurants = df_top_1500[df_top_1500['type'] == 'Restaurant'].head(10)

print("Complete information about first 10 restaurants:")
print("=" * 80)

for i, (idx, row) in enumerate(restaurants.iterrows(), 1):
    print(f"\n{i}. {row['name']}")
    print(f"   ID: {row['fsq_place_id']}")
    print(f"   Address: {row['address']}")
    print(f"   Coordinates: {row['latitude']:.6f}, {row['longitude']:.6f}")
    print(f"   Phone: {row['tel']}")
    print(f"   Website: {row['website']}")
    print(f"   Instagram: {row['instagram']}")
    print(f"   Score: {row['score']}")
    print(f"   Geo-cluster: {row['geo_cluster']}")
    print(f"   Categories: {row['categories_list']}")

print("\n" + "=" * 80)
print(f"Total restaurants in dataset: {len(df_top_1500[df_top_1500['type'] == 'Restaurant'])}")
print(f"Total dataset size: {len(df_top_1500)} establishments")
# Out:
# Complete information about first 10 restaurants:
# ================================================================================
#
# 1. G&T Gourmet
#    ID: 5ae16b8d270ee70039f23ac1
#    Address: Русаковская ул., 24
#    Coordinates: 55.787831, 37.680659
#    Phone: 8 (800) 700-15-50
#    Website: http://www.gtgourmet.com
#    Instagram: gtgourmet
#    Score: 44
#    Geo-cluster: 34
#    Categories: ['Dining and Drinking > Restaurant > Modern European Restaurant']
#
# 2. Винный базар
#    ID: 58cd506846563a6c4bd7527e
#    Address: Петровский бул., 15, стр. 1
#    Coordinates: 55.768191, 37.615991
#    Phone: 8 (495) 699-18-60
#    Website: http://vinniybazar.ru
#    Instagram: vinniy_bazar_petrovskiy
#    Score: 42
#    Geo-cluster: 40
#    Categories: ['Dining and Drinking > Bar > Wine Bar', 'Dining and Drinking > Restaurant']
#
# 3. Støy Craft Bar
#    ID: 5b37b96aca18ea002c8b0bd4
#    Address: Валовая ул., 30
#    Coordinates: 55.730199, 37.626827
#    Phone: 8 (495) 142-76-30
#    Website: https://www.tripadvisor.com/Restaurant_Review-g298484-d14951219-Reviews-Stoy_Craft_Bar-Moscow_Central_Russia.html
#    Instagram: stoy.bar
#    Score: 42
#    Geo-cluster: 13
#    Categories: ['Dining and Drinking > Bar > Beer Bar', 'Dining and Drinking > Restaurant > Burger Joint']
#
# 4. Craft Kitchen
#    ID: 5923f2a5356b49419657d471
#    Address: ТРЦ «Европейский»
#    Coordinates: 55.745262, 37.567908
#    Phone: None
#    Website: http://www.ilfornogroup.ru
#    Instagram: craftkitchenmoscow
#    Score: 37
#    Geo-cluster: 43
#    Categories: ['Dining and Drinking > Restaurant > Gastropub']
#
# 5. Crafted Grill Bar
#    ID: 578e7953498e64162edc515f
#    Address: Москва, проезд Сокольнического Круга, 5
#    Coordinates: 55.795519, 37.678379
#    Phone: 8 (966) 355-48-88
#    Website: http://craftedgrillbar.ru
#    Instagram: None
#    Score: 36
#    Geo-cluster: 34
#    Categories: ['Dining and Drinking > Restaurant > BBQ Joint']
#
# 6. № 13
#    ID: 5de4133661260b000742784d
#    Address: 13 Malaya Bronnaya Street
#    Coordinates: 55.759825, 37.596114
#    Phone: 8 (495) 695-58-88
#    Website: https://13restaurant.ru
#    Instagram: 13_restaurant
#    Score: 34
#    Geo-cluster: 26
#    Categories: ['Dining and Drinking > Restaurant > Modern European Restaurant']
#
# 7. Pinzeria by Bontempi
#    ID: 546e146b498e86d7178d336d
#    Address: Большой Знаменский пер., 2, стр. 3
#    Coordinates: 55.746038, 37.602141
#    Phone: 8 (499) 678-30-09
#    Website: http://pinzeria.ru
#    Instagram: pinzzzeria
#    Score: 34
#    Geo-cluster: 43
#    Categories: ['Dining and Drinking > Restaurant > Pizzeria', 'Dining and Drinking > Restaurant > Italian Restaurant']
#
# 8. Cavina
#    ID: 603ba58b48c3d830d1d34750
#    Address: Мансуровский переулок, 10, стр.2
#    Coordinates: 55.740226, 37.593749
#    Phone: 8 (495) 637-21-58
#    Website: https://www.cavinabar.ru
#    Instagram: cavina_gastrobar
#    Score: 34
#    Geo-cluster: 43
#    Categories: ['Dining and Drinking > Bar > Wine Bar', 'Dining and Drinking > Restaurant > Spanish Restaurant', 'Retail > Food and Beverage Retail > Wine Store']
#
# 9. Айна
#    ID: 63ffa7fe7d42d570c8d4a80b
#    Address: ул. Остоженка, 14/2
#    Coordinates: 55.741789, 37.599192
#    Phone: 8 (495) 103-10-23
#    Website: https://ainarest.ru
#    Instagram: aina.rest
#    Score: 34
#    Geo-cluster: 43
#    Categories: ['Dining and Drinking > Restaurant']
#
# 10. Prime
#    ID: 5372ee93498e7fde9fe2dde4
#    Address: Тверская ул., 20
#    Coordinates: 55.765446, 37.603528
#    Phone: 8 (495) 664-23-63
#    Website: http://www.prime-star.ru
#    Instagram: prime_star_cafe
#    Score: 34
#    Geo-cluster: 40
#    Categories: ['Dining and Drinking > Restaurant > Sandwich Spot']
#
# ================================================================================
# Total restaurants in dataset: 500
# Total dataset size: 1355 establishments

# %%
data_lens_export = df_top_1500.copy()


data_lens_export['geo_cluster_name'] = 'Cluster ' + data_lens_export['geo_cluster'].astype(str)


data_lens_export['point_size'] = data_lens_export['score'] / data_lens_export['score'].max() * 10


color_mapping = {'Restaurant': '#FF6B6B', 'Bar': '#4ECDC4', 'Coffee': '#45B7D1'}
data_lens_export['color'] = data_lens_export['type'].map(color_mapping)


data_lens_export[[
    'fsq_place_id', 'name', 'address', 'latitude', 'longitude',
    'type', 'score', 'geo_cluster', 'geo_cluster_name', 'point_size', 'color',
    'tel', 'website', 'instagram'
]].to_csv('data/processed/moscow_data_lens_export.csv', index=False, encoding='utf-8')

print("Данные для Data Lens сохранены в файл: moscow_data_lens_export.csv")
print("\nСтруктура данных для визуализации:")
print(f"- Всего точек: {len(data_lens_export)}")
print(f"- Типы заведений: {dict(data_lens_export['type'].value_counts())}")
print(f"- Гео-кластеры: {data_lens_export['geo_cluster'].nunique()}")
print(f"- Диапазон скоринга: {data_lens_export['score'].min()} - {data_lens_export['score'].max()}")
# Out:
# Данные для Data Lens сохранены в файл: moscow_data_lens_export.csv
#
# Структура данных для визуализации:
# - Всего точек: 1355
# - Типы заведений: {'Restaurant': np.int64(500), 'Bar': np.int64(500), 'Coffee': np.int64(355)}
# - Гео-кластеры: 44
# - Диапазон скоринга: 8 - 44

# %%
df_top_100 = df_top_1500.nlargest(100, 'score').copy()

print(f"Топ-100 заведений Москвы:")
print("=" * 50)


for i, (idx, row) in enumerate(df_top_100.iterrows(), 1):
    print(f"\n{i}. {row['name']}")
    print(f"   Тип: {row['type']}")
    print(f"   Score: {row['score']}")
    print(f"   Адрес: {row['address']}")
    print(f"   Телефон: {row['tel'] if pd.notna(row['tel']) else 'нет'}")
    print(f"   Сайт: {row['website'] if pd.notna(row['website']) else 'нет'}")
    print(f"   Instagram: {row['instagram'] if pd.notna(row['instagram']) else 'нет'}")
    print(f"   Гео-кластер: {row['geo_cluster']}")


df_top_100_for_enrichment = df_top_100[[
    'fsq_place_id', 'name', 'address', 'tel', 'website', 'instagram',
    'type', 'score', 'geo_cluster'
]].copy()


df_top_100_for_enrichment['price_level'] = ''
df_top_100_for_enrichment['atmosphere'] = ''
df_top_100_for_enrichment['terrace'] = ''
df_top_100_for_enrichment['parking'] = ''
df_top_100_for_enrichment['features'] = ''
df_top_100_for_enrichment['cuisine_details'] = ''
df_top_100_for_enrichment['notes'] = ''


df_top_100_for_enrichment.to_csv('top_100_moscow_restaurants_for_manual_enrichment.csv',
                                index=False, encoding='utf-8')

print(f"\nСохранено 100 заведений в 'top_100_moscow_restaurants_for_manual_enrichment.csv'")
print(f"Распределение по типам:")
print(df_top_100['type'].value_counts())
print(f" Диапазон score: {df_top_100['score'].min()} - {df_top_100['score'].max()}")
# Out:
# Топ-100 заведений Москвы:
# ==================================================
#
# 1. G&T Gourmet
#    Тип: Restaurant
#    Score: 44
#    Адрес: Русаковская ул., 24
#    Телефон: 8 (800) 700-15-50
#    Сайт: http://www.gtgourmet.com
#    Instagram: gtgourmet
#    Гео-кластер: 34
#
# 2. Винный базар
#    Тип: Restaurant
#    Score: 42
#    Адрес: Петровский бул., 15, стр. 1
#    Телефон: 8 (495) 699-18-60
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_petrovskiy
#    Гео-кластер: 40
#
# 3. Støy Craft Bar
#    Тип: Restaurant
#    Score: 42
#    Адрес: Валовая ул., 30
#    Телефон: 8 (495) 142-76-30
#    Сайт: https://www.tripadvisor.com/Restaurant_Review-g298484-d14951219-Reviews-Stoy_Craft_Bar-Moscow_Central_Russia.html
#    Instagram: stoy.bar
#    Гео-кластер: 13
#
# 4. Crafter Bar
#    Тип: Bar
#    Score: 39
#    Адрес: Малый Палашевский пер., 6
#    Телефон: 8 (968) 029-88-42
#    Сайт: http://www.crafterbar.ru
#    Instagram: crafter_bar
#    Гео-кластер: 26
#
# 5. Невинный
#    Тип: Bar
#    Score: 39
#    Адрес: ул. Усачёва, 26
#    Телефон: 8 (925) 577-77-30
#    Сайт: https://nevinniybar.ru
#    Instagram: nevinniy.msk
#    Гео-кластер: 43
#
# 6. HopHead Craft Beer Pub
#    Тип: Bar
#    Score: 39
#    Адрес: ул. Фридриха Энгельса, 20, стр. 1
#    Телефон: 8 (968) 810-18-88
#    Сайт: http://www.hophead.ru
#    Instagram: hopheadpub
#    Гео-кластер: 34
#
# 7. Винный базар
#    Тип: Bar
#    Score: 39
#    Адрес: Большая Садовая ул., 1
#    Телефон: 8 (499) 341-43-00
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_sadovaya
#    Гео-кластер: 26
#
# 8. Goos'to wine, винный бар
#    Тип: Bar
#    Score: 39
#    Адрес: Театральный проезд, 3с3
#    Телефон: 8 (909) 910-48-41
#    Сайт: http://goostowine.ru
#    Instagram: goostowine
#    Гео-кластер: 40
#
# 9. Винный базар
#    Тип: Bar
#    Score: 39
#    Адрес: Комсомольский просп., 14/1, корп. 2
#    Телефон: 8 (499) 246-64-66
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_komsomolsky
#    Гео-кластер: 43
#
# 10. Howard Loves Craft
#    Тип: Bar
#    Score: 39
#    Адрес: Тверская ул., 15
#    Телефон: 8 (968) 500-07-45
#    Сайт: http://howardlovescraft.ru
#    Instagram: howardlovescraft
#    Гео-кластер: 40
#
# 11. Craft Kitchen
#    Тип: Restaurant
#    Score: 37
#    Адрес: ТРЦ «Европейский»
#    Телефон: нет
#    Сайт: http://www.ilfornogroup.ru
#    Instagram: craftkitchenmoscow
#    Гео-кластер: 43
#
# 12. Crafted Grill Bar
#    Тип: Restaurant
#    Score: 36
#    Адрес: Москва, проезд Сокольнического Круга, 5
#    Телефон: 8 (966) 355-48-88
#    Сайт: http://craftedgrillbar.ru
#    Instagram: нет
#    Гео-кластер: 34
#
# 13. № 13
#    Тип: Restaurant
#    Score: 34
#    Адрес: 13 Malaya Bronnaya Street
#    Телефон: 8 (495) 695-58-88
#    Сайт: https://13restaurant.ru
#    Instagram: 13_restaurant
#    Гео-кластер: 26
#
# 14. Pinzeria by Bontempi
#    Тип: Restaurant
#    Score: 34
#    Адрес: Большой Знаменский пер., 2, стр. 3
#    Телефон: 8 (499) 678-30-09
#    Сайт: http://pinzeria.ru
#    Instagram: pinzzzeria
#    Гео-кластер: 43
#
# 15. Cavina
#    Тип: Restaurant
#    Score: 34
#    Адрес: Мансуровский переулок, 10, стр.2
#    Телефон: 8 (495) 637-21-58
#    Сайт: https://www.cavinabar.ru
#    Instagram: cavina_gastrobar
#    Гео-кластер: 43
#
# 16. Айна
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Остоженка, 14/2
#    Телефон: 8 (495) 103-10-23
#    Сайт: https://ainarest.ru
#    Instagram: aina.rest
#    Гео-кластер: 43
#
# 17. Prime
#    Тип: Restaurant
#    Score: 34
#    Адрес: Тверская ул., 20
#    Телефон: 8 (495) 664-23-63
#    Сайт: http://www.prime-star.ru
#    Instagram: prime_star_cafe
#    Гео-кластер: 40
#
# 18. Prime
#    Тип: Restaurant
#    Score: 34
#    Адрес: Тверская улица, 19А
#    Телефон: 8 (495) 664-23-63
#    Сайт: http://www.prime-star.ru
#    Instagram: prime_star_cafe
#    Гео-кластер: 26
#
# 19. Twins
#    Тип: Restaurant
#    Score: 34
#    Адрес: Малая Бронная ул., 13
#    Телефон: 8 (495) 695-45-10
#    Сайт: http://twinsmoscow.ru
#    Instagram: twinspatriki
#    Гео-кластер: 26
#
# 20. Неуловимый Джо
#    Тип: Restaurant
#    Score: 34
#    Адрес: Алтайская ул., 4
#    Телефон: 8 (495) 792-79-73
#    Сайт: https://www.saloonjoe.com
#    Instagram: saloonjoe
#    Гео-кластер: 22
#
# 21. Petit Café
#    Тип: Restaurant
#    Score: 34
#    Адрес: Пречистенская наб., 15, стр. 2
#    Телефон: 8 (495) 744-62-19
#    Сайт: http://petercafe.ru
#    Instagram: petitcafe_ru
#    Гео-кластер: 43
#
# 22. Silver Panda
#    Тип: Restaurant
#    Score: 34
#    Адрес: Берсеневский пер., 2, стр. 1
#    Телефон: 8 (495) 540-55-94
#    Сайт: http://www.silverpanda.ru
#    Instagram: officialsilverpanda
#    Гео-кластер: 40
#
# 23. Урожай
#    Тип: Restaurant
#    Score: 34
#    Адрес: Берсеневская наб., 6, стр 3
#    Телефон: 8 (495) 792-06-46
#    Сайт: http://rodnoyurozhay.ru
#    Instagram: cafeurozhay
#    Гео-кластер: 43
#
# 24. T.G.I. Friday’s
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево D / SVO D (международные рейсы)
#    Телефон: 8 (495) 730-68-11
#    Сайт: http://www.tgifridays.ru/
#    Instagram: tgif_russia
#    Гео-кластер: 41
#
# 25. T.G.I. Friday's
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево D / SVO D (внутренние рейсы)
#    Телефон: 8 (965) 422-43-56
#    Сайт: http://www.tgifridays.ru/
#    Instagram: tgif_russia
#    Гео-кластер: 41
#
# 26. Black Thai
#    Тип: Restaurant
#    Score: 34
#    Адрес: Большой Путинковский пер., 5
#    Телефон: 8 (495) 699-22-10
#    Сайт: http://blackthai.ru
#    Instagram: restaurantblackthai
#    Гео-кластер: 40
#
# 27. Пороселло
#    Тип: Restaurant
#    Score: 34
#    Адрес: Неглинная ул., 16, стр. 2
#    Телефон: 8 (499) 579-83-03
#    Сайт: http://porosello.ru
#    Instagram: porosello
#    Гео-кластер: 40
#
# 28. Shortlist. Books and Spirits
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Петровка, 26, стр. 3
#    Телефон: 8 (499) 964-66-26
#    Сайт: http://shortlistbar.ru
#    Instagram: shortlistbar
#    Гео-кластер: 40
#
# 29. Вареничная № 1
#    Тип: Restaurant
#    Score: 34
#    Адрес: пл. Киевского Вокзала, 2
#    Телефон: 8 (909) 677-34-54
#    Сайт: http://varenichnaya.ru
#    Instagram: varenichnaya1
#    Гео-кластер: 43
#
# 30. Mina
#    Тип: Restaurant
#    Score: 34
#    Адрес: Малая Никитская ул., 16
#    Телефон: 8 (499) 390-50-90
#    Сайт: https://probka.org/restaurants/mina-msk/
#    Instagram: mina_rest
#    Гео-кластер: 26
#
# 31. Гвидон
#    Тип: Restaurant
#    Score: 34
#    Адрес: Большая Никитская ул., 5
#    Телефон: 8 (495) 258-08-88
#    Сайт: https://gvidon.wrf.su
#    Instagram: gvidon.rest.wrf
#    Гео-кластер: 40
#
# 32. Тажинерия Moroccan
#    Тип: Restaurant
#    Score: 34
#    Адрес: Даниловский рынок
#    Телефон: 8 (925) 772-56-65
#    Сайт: http://moroccanfood.ru
#    Instagram: tajinerie
#    Гео-кластер: 13
#
# 33. Щепка
#    Тип: Restaurant
#    Score: 34
#    Адрес: Даниловский рынок
#    Телефон: 8 (499) 110-47-09
#    Сайт: http://shepka.shop
#    Instagram: shepkashop
#    Гео-кластер: 13
#
# 34. Prawn Bar
#    Тип: Restaurant
#    Score: 34
#    Адрес: Даниловский рынок
#    Телефон: 8 (495) 954-50-00
#    Сайт: http://prawnbar.ru
#    Instagram: prawn_bar
#    Гео-кластер: 13
#
# 35. Новая Азия
#    Тип: Restaurant
#    Score: 34
#    Адрес: 2-я Рощинская ул., 1А
#    Телефон: 8 (495) 958-60-83
#    Сайт: http://asianew.ru
#    Instagram: asianewrest
#    Гео-кластер: 13
#
# 36. Профессор Пуф
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Волхонка, 9, стр. 1
#    Телефон: 8 (916) 054-43-05
#    Сайт: http://professorpuf.ru
#    Instagram: professorpuf
#    Гео-кластер: 40
#
# 37. La Scarpetta
#    Тип: Restaurant
#    Score: 34
#    Адрес: Оболенский пер., 9, корп. 1
#    Телефон: 8 (499) 246-62-28
#    Сайт: http://lascarpetta.ru
#    Instagram: la_scarpetta_msc
#    Гео-кластер: 43
#
# 38. Государь
#    Тип: Restaurant
#    Score: 34
#    Адрес: Лобненская ул., 11
#    Телефон: 8 (495) 636-27-89
#    Сайт: http://banket-gosudar.ru
#    Instagram: gosudar_banket
#    Гео-кластер: 31
#
# 39. I Like Grill
#    Тип: Restaurant
#    Score: 34
#    Адрес: БЦ «Строганов»
#    Телефон: 8 (903) 253-41-41
#    Сайт: http://perelmanpeople.com
#    Instagram: ilikegrill
#    Гео-кластер: 43
#
# 40. Абу Гош
#    Тип: Restaurant
#    Score: 34
#    Адрес: пер. Сивцев Вражек, 42, стр. 5
#    Телефон: 8 (495) 226-92-02
#    Сайт: http://www.abugosh.ru
#    Instagram: abugosh.moscow
#    Гео-кластер: 43
#
# 41. Оджахури
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Усачёва, 26
#    Телефон: 8 (969) 100-01-10
#    Сайт: http://ojakhuri.ru
#    Instagram: ojakhuri
#    Гео-кластер: 43
#
# 42. Нам
#    Тип: Restaurant
#    Score: 34
#    Адрес: Саввинская наб., 19, стр. 1а
#    Телефон: 8 (495) 798-52-83
#    Сайт: https://m.vk.com/namcafe
#    Instagram: nam_cafe
#    Гео-кластер: 43
#
# 43. SML Deli Coffee Shop
#    Тип: Restaurant
#    Score: 34
#    Адрес: 24С48 Luzhniki Street
#    Телефон: 8 (916) 725-28-01
#    Сайт: http://smlcafe.ru
#    Instagram: sml_cafe
#    Гео-кластер: 21
#
# 44. Жаровня
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Б. Дмитровка, 11
#    Телефон: 8 (495) 909-10-79
#    Сайт: http://www.жаровня.рф
#    Instagram: zharovnya
#    Гео-кластер: 40
#
# 45. Щепка
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Усачёва, 26
#    Телефон: 8 (929) 639-13-69
#    Сайт: http://shepka.shop
#    Instagram: shepkashop
#    Гео-кластер: 43
#
# 46. YURA
#    Тип: Restaurant
#    Score: 34
#    Адрес: StandArt Hotel 5*, 2 floor
#    Телефон: 8 (495) 587-77-25
#    Сайт: https://www.standarthotel.com/restaurants-and-bars/yura-restaurant/
#    Instagram: yura.restaurant
#    Гео-кластер: 40
#
# 47. Lin Bistro
#    Тип: Restaurant
#    Score: 34
#    Адрес: Ostozhenka, 27/1
#    Телефон: 8 (499) 226-16-27
#    Сайт: https://linbistro.ru
#    Instagram: lino_bistro
#    Гео-кластер: 43
#
# 48. 5 океан
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево-F, аэропорт
#    Телефон: 8 (495) 578-31-35
#    Сайт: http://www.aeropit.ru/places/pyatyy-okean/
#    Instagram: svo_5_ocean
#    Гео-кластер: 41
#
# 49. Lunch Point
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево F
#    Телефон: 8 (495) 578-82-32
#    Сайт: http://www.aeropit.ru/places/lunch-point/
#    Instagram: lunch_point_svo
#    Гео-кластер: 41
#
# 50. Гамбринус
#    Тип: Restaurant
#    Score: 34
#    Адрес: 1-я владимирская  д. 9
#    Телефон: 8 (495) 306-37-64
#    Сайт: http://www.gambrinusbar.ru
#    Instagram: gambrinusmoscow
#    Гео-кластер: 22
#
# 51. Laksa & Co
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Усачёва, 26
#    Телефон: 8 (977) 251-88-99
#    Сайт: https://laksa.ru
#    Instagram: laksa_kitchen
#    Гео-кластер: 43
#
# 52. Лима
#    Тип: Restaurant
#    Score: 34
#    Адрес: Дружинниковская ул., 15
#    Телефон: 8 (906) 036-96-58
#    Сайт: https://www.limamoscow.ru
#    Instagram: lima_restoran
#    Гео-кластер: 26
#
# 53. Моремясо
#    Тип: Restaurant
#    Score: 34
#    Адрес: 1-й Красногвардейский пр., 15
#    Телефон: 8 (499) 390-44-44
#    Сайт: http://moremyaso.com
#    Instagram: moremyaso
#    Гео-кластер: 21
#
# 54. Bella Pasta
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Красная Пресня, 6/2, стр. 1
#    Сайт: http://aviator.city
#    Instagram: aviator.city
#    Гео-кластер: 21
#
# 92. Рыбная мануфактура № 1
#    Тип: Restaurant
#    Score: 34
#    Адрес: Пресненская наб., 2 (ТЦ "Афимолл", 5 этаж)
#    Телефон: 8 (916) 137-46-29
#    Сайт: https://rm-1.ru/cafe/afimoll
#    Instagram: rybnaya_manufaktura
#    Гео-кластер: 21
#
# 93. RIBAMBELLE In the City
#    Тип: Restaurant
#    Score: 34
#    Адрес: Ленинградское ш., 16а, стр. 4
#    Телефон: 8 (495) 021-65-22
#    Сайт: https://ribambelle.ru
#    Instagram: ribambelleru
#    Гео-кластер: 0
#
# 94. Никуда не едем
#    Тип: Restaurant
#    Score: 34
#    Адрес: Трёхгорная мануфактура
#    Телефон: 8 (495) 926-23-22
#    Сайт: http://nikudaneedem.ru
#    Instagram: nikudaneedem
#    Гео-кластер: 21
#
# 95. Чихо
#    Тип: Restaurant
#    Score: 34
#    Адрес: Цветной б-р, д.15, стр.1
#    Телефон: 8 (495) 208-93-48
#    Сайт: http://chiho.ru
#    Instagram: chiho_china
#    Гео-кластер: 40
#
# 96. RA'MEN
#    Тип: Restaurant
#    Score: 34
#    Адрес: Цветной бул., 21, стр. 7
#    Телефон: 8 (985) 550-81-52
#    Сайт: https://ramen.moscow
#    Instagram: ramen.moscow
#    Гео-кластер: 40
#
# 97. Черта
#    Тип: Restaurant
#    Score: 34
#    Адрес: Брошевский переулок 6, стр. 1
#    Телефон: 8 (964) 791-44-26
#    Сайт: http://chertabar.ru
#    Instagram: chertabar
#    Гео-кластер: 34
#
# 98. Pâté & Co
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Балчуг, 3/2
#    Телефон: 8 (495) 252-07-06
#    Сайт: http://www.patecafe.ru
#    Instagram: pate_brasserie
#    Гео-кластер: 40
#
# 99. Устричная и Шампанский бар
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Варварка 6 ст3
#    Телефон: 8 (495) 531-09-50
#    Сайт: http://zaryadyegastrocenter.ru
#    Instagram: zaryadye_gastrocenter
#    Гео-кластер: 40
#
# 100. Просто Вкусно Пироги
#    Тип: Restaurant
#    Score: 34
#    Адрес: Мира проспект 150
#    Телефон: 8 (495) 120-50-12
#    Сайт: https://pirogi.love
#    Instagram: prostovkusnopirogi
#    Гео-кластер: 49
#
# Сохранено 100 заведений в 'top_100_moscow_restaurants_for_manual_enrichment.csv'
# Распределение по типам:
# type
# Restaurant    93
# Bar            7
# Name: count, dtype: int64
#  Диапазон score: 34 - 44

# %%
import os


os.makedirs('top_100_restaurants', exist_ok=True)

for i, (idx, row) in enumerate(df_top_100.iterrows(), 1):
    restaurant_data = {
        'fsq_place_id': row['fsq_place_id'],
        'name': row['name'],
        'address': row['address'],
        'latitude': row['latitude'],
        'longitude': row['longitude'],
        'tel': row['tel'] if pd.notna(row['tel']) else '',
        'website': row['website'] if pd.notna(row['website']) else '',
        'instagram': row['instagram'] if pd.notna(row['instagram']) else '',
        'type': row['type'],
        'score': row['score'],
        'geo_cluster': row['geo_cluster'],
        'price_level': '',
        'atmosphere': '',
        'terrace': '',
        'parking': '',
        'features': '',
        'cuisine_details': '',
        'notes': ''
    }


    safe_name = "".join(c for c in row['name'] if c.isalnum() or c in (' ', '-', '_')).rstrip()
    filename = f"{i:03d}_{safe_name}.csv"


    pd.DataFrame([restaurant_data]).to_csv(
        f'top_100_restaurants/{filename}',
        index=False,
        encoding='utf-8'
    )

print(f" Сохранено 100 отдельных файлов в папку 'top_100_restaurants/'")
# Out:
#  Сохранено 100 отдельных файлов в папку 'top_100_restaurants/'

# %%
df_top_100 = df_top_1500.nlargest(100, 'score').copy()

print(f"Топ-100 заведений Москвы:")
print("=" * 80)

for i, (idx, row) in enumerate(df_top_100.iterrows(), 1):
    print(f"\n{i}. {row['name']}")
    print(f"   Тип: {row['type']}")
    print(f"   Score: {row['score']}")
    print(f"   Адрес: {row['address']}")
    print(f"   Широта: {row['latitude']:.6f}")
    print(f"   Долгота: {row['longitude']:.6f}")
    print(f"   Телефон: {row['tel'] if pd.notna(row['tel']) else 'нет'}")
    print(f"   Сайт: {row['website'] if pd.notna(row['website']) else 'нет'}")
    print(f"   Instagram: {row['instagram'] if pd.notna(row['instagram']) else 'нет'}")
    print(f"   Гео-кластер: {row['geo_cluster']}")

# Сохранение с координатами
df_top_100_for_enrichment = df_top_100[[
    'fsq_place_id', 'name', 'address', 'latitude', 'longitude',
    'tel', 'website', 'instagram', 'type', 'score', 'geo_cluster'
]].copy()

# Добавляем поля для ручного обогащения
df_top_100_for_enrichment['price_level'] = ''
df_top_100_for_enrichment['atmosphere'] = ''
df_top_100_for_enrichment['terrace'] = ''
df_top_100_for_enrichment['parking'] = ''
df_top_100_for_enrichment['features'] = ''
df_top_100_for_enrichment['cuisine_details'] = ''
df_top_100_for_enrichment['notes'] = ''

# Сохраняем файл
df_top_100_for_enrichment.to_csv('top_100_moscow_restaurants_with_coordinates.csv',
                                index=False, encoding='utf-8')

print(f"\n=== СВОДНАЯ ИНФОРМАЦИЯ ===")
print(f"Сохранено 100 заведений в 'top_100_moscow_restaurants_with_coordinates.csv'")
print(f"Распределение по типам:")
print(df_top_100['type'].value_counts())
print(f"Диапазон score: {df_top_100['score'].min()} - {df_top_100['score'].max()}")
print(f"Диапазон широт: {df_top_100['latitude'].min():.6f} - {df_top_100['latitude'].max():.6f}")
print(f"Диапазон долгот: {df_top_100['longitude'].min():.6f} - {df_top_100['longitude'].max():.6f}")

# Дополнительная статистика по координатам
print(f"\n=== ГЕОГРАФИЧЕСКАЯ СТАТИСТИКА ===")
print(f"Средняя широта: {df_top_100['latitude'].mean():.6f}")
print(f"Средняя долгота: {df_top_100['longitude'].mean():.6f}")
print(f"Уникальных гео-кластеров в топ-100: {df_top_100['geo_cluster'].nunique()}")
# Out:
# Топ-100 заведений Москвы:
# ================================================================================
#
# 1. G&T Gourmet
#    Тип: Restaurant
#    Score: 44
#    Адрес: Русаковская ул., 24
#    Широта: 55.787831
#    Долгота: 37.680659
#    Телефон: 8 (800) 700-15-50
#    Сайт: http://www.gtgourmet.com
#    Instagram: gtgourmet
#    Гео-кластер: 34
#
# 2. Винный базар
#    Тип: Restaurant
#    Score: 42
#    Адрес: Петровский бул., 15, стр. 1
#    Широта: 55.768191
#    Долгота: 37.615991
#    Телефон: 8 (495) 699-18-60
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_petrovskiy
#    Гео-кластер: 40
#
# 3. Støy Craft Bar
#    Тип: Restaurant
#    Score: 42
#    Адрес: Валовая ул., 30
#    Широта: 55.730199
#    Долгота: 37.626827
#    Телефон: 8 (495) 142-76-30
#    Сайт: https://www.tripadvisor.com/Restaurant_Review-g298484-d14951219-Reviews-Stoy_Craft_Bar-Moscow_Central_Russia.html
#    Instagram: stoy.bar
#    Гео-кластер: 13
#
# 4. Crafter Bar
#    Тип: Bar
#    Score: 39
#    Адрес: Малый Палашевский пер., 6
#    Широта: 55.765172
#    Долгота: 37.602338
#    Телефон: 8 (968) 029-88-42
#    Сайт: http://www.crafterbar.ru
#    Instagram: crafter_bar
#    Гео-кластер: 26
#
# 5. Невинный
#    Тип: Bar
#    Score: 39
#    Адрес: ул. Усачёва, 26
#    Широта: 55.727382
#    Долгота: 37.567756
#    Телефон: 8 (925) 577-77-30
#    Сайт: https://nevinniybar.ru
#    Instagram: nevinniy.msk
#    Гео-кластер: 43
#
# 6. HopHead Craft Beer Pub
#    Тип: Bar
#    Score: 39
#    Адрес: ул. Фридриха Энгельса, 20, стр. 1
#    Широта: 55.772393
#    Долгота: 37.682724
#    Телефон: 8 (968) 810-18-88
#    Сайт: http://www.hophead.ru
#    Instagram: hopheadpub
#    Гео-кластер: 34
#
# 7. Винный базар
#    Тип: Bar
#    Score: 39
#    Адрес: Большая Садовая ул., 1
#    Широта: 55.766130
#    Долгота: 37.590879
#    Телефон: 8 (499) 341-43-00
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_sadovaya
#    Гео-кластер: 26
#
# 8. Goos'to wine, винный бар
#    Тип: Bar
#    Score: 39
#    Адрес: Театральный проезд, 3с3
#    Широта: 55.759873
#    Долгота: 37.622391
#    Телефон: 8 (909) 910-48-41
#    Сайт: http://goostowine.ru
#    Instagram: goostowine
#    Гео-кластер: 40
#
# 9. Винный базар
#    Тип: Bar
#    Score: 39
#    Адрес: Комсомольский просп., 14/1, корп. 2
#    Широта: 55.731396
#    Долгота: 37.590645
#    Телефон: 8 (499) 246-64-66
#    Сайт: http://vinniybazar.ru
#    Instagram: vinniy_bazar_komsomolsky
#    Гео-кластер: 43
#
# 10. Howard Loves Craft
#    Тип: Bar
#    Score: 39
#    Адрес: Тверская ул., 15
#    Широта: 55.762514
#    Долгота: 37.608070
#    Телефон: 8 (968) 500-07-45
#    Сайт: http://howardlovescraft.ru
#    Instagram: howardlovescraft
#    Гео-кластер: 40
#
# 11. Craft Kitchen
#    Тип: Restaurant
#    Score: 37
#    Адрес: ТРЦ «Европейский»
#    Широта: 55.745262
#    Долгота: 37.567908
#    Телефон: нет
#    Адрес: Берсеневский пер., 2, стр. 1
#    Широта: 55.741221
#    Долгота: 37.609508
#    Телефон: 8 (495) 540-55-94
#    Сайт: http://www.silverpanda.ru
#    Instagram: officialsilverpanda
#    Гео-кластер: 40
#
# 23. Урожай
#    Тип: Restaurant
#    Score: 34
#    Адрес: Берсеневская наб., 6, стр 3
#    Широта: 55.740673
#    Долгота: 37.608640
#    Телефон: 8 (495) 792-06-46
#    Сайт: http://rodnoyurozhay.ru
#    Instagram: cafeurozhay
#    Гео-кластер: 43
#
# 24. T.G.I. Friday’s
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево D / SVO D (международные рейсы)
#    Широта: 55.963309
#    Долгота: 37.407495
#    Телефон: 8 (495) 730-68-11
#    Сайт: http://www.tgifridays.ru/
#    Instagram: tgif_russia
#    Гео-кластер: 41
#
# 25. T.G.I. Friday's
#    Тип: Restaurant
#    Score: 34
#    Адрес: Шереметьево D / SVO D (внутренние рейсы)
#    Широта: 55.964147
#    Долгота: 37.405527
#    Телефон: 8 (965) 422-43-56
#    Сайт: http://www.tgifridays.ru/
#    Instagram: tgif_russia
#    Гео-кластер: 41
#
# 26. Black Thai
#    Тип: Restaurant
#    Score: 34
#    Адрес: Большой Путинковский пер., 5
#    Широта: 55.767078
#    Долгота: 37.607383
#    Телефон: 8 (495) 699-22-10
#    Сайт: http://blackthai.ru
#    Instagram: restaurantblackthai
#    Гео-кластер: 40
#
# 27. Пороселло
#    Тип: Restaurant
#    Score: 34
#    Адрес: Неглинная ул., 16, стр. 2
#    Широта: 55.765030
#    Долгота: 37.620387
#    Телефон: 8 (499) 579-83-03
#    Сайт: http://porosello.ru
#    Instagram: porosello
#    Гео-кластер: 40
#
# 28. Shortlist. Books and Spirits
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Петровка, 26, стр. 3
#    Широта: 55.765865
#    Долгота: 37.615705
#    Телефон: 8 (499) 964-66-26
#    Сайт: http://shortlistbar.ru
#    Instagram: shortlistbar
#    Гео-кластер: 40
#
# 29. Вареничная № 1
#    Тип: Restaurant
#    Score: 34
#    Адрес: пл. Киевского Вокзала, 2
#    Широта: 55.744656
#    Долгота: 37.568133
#    Телефон: 8 (909) 677-34-54
#    Сайт: http://varenichnaya.ru
#    Instagram: varenichnaya1
#    Гео-кластер: 43
#
# 30. Mina
#    Тип: Restaurant
#    Score: 34
#    Адрес: Малая Никитская ул., 16
#    Широта: 55.758586
#    Долгота: 37.591406
#    Телефон: 8 (499) 390-50-90
#    Сайт: https://probka.org/restaurants/mina-msk/
#    Instagram: mina_rest
#    Гео-кластер: 26
#
# 31. Гвидон
#    Тип: Restaurant
#    Score: 34
#    Адрес: Большая Никитская ул., 5
#    Широта: 55.755425
#    Долгота: 37.608681
#    Телефон: 8 (495) 258-08-88
#    Сайт: https://gvidon.wrf.su
#    Instagram: gvidon.rest.wrf
#    Гео-кластер: 40
#
# 32. Тажинерия Moroccan
#    Тип: Restaurant
#    Score: 34
#    Адрес: Даниловский рынок
#    Широта: 55.712046
#    Широта: 55.757084
#    Долгота: 37.563965
#    Телефон: 8 (495) 926-23-22
#    Сайт: http://nikudaneedem.ru
#    Instagram: nikudaneedem
#    Гео-кластер: 21
#
# 95. Чихо
#    Тип: Restaurant
#    Score: 34
#    Адрес: Цветной б-р, д.15, стр.1
#    Широта: 55.771156
#    Долгота: 37.620390
#    Телефон: 8 (495) 208-93-48
#    Сайт: http://chiho.ru
#    Instagram: chiho_china
#    Гео-кластер: 40
#
# 96. RA'MEN
#    Тип: Restaurant
#    Score: 34
#    Адрес: Цветной бул., 21, стр. 7
#    Широта: 55.772169
#    Долгота: 37.619585
#    Телефон: 8 (985) 550-81-52
#    Сайт: https://ramen.moscow
#    Instagram: ramen.moscow
#    Гео-кластер: 40
#
# 97. Черта
#    Тип: Restaurant
#    Score: 34
#    Адрес: Брошевский переулок 6, стр. 1
#    Широта: 55.736282
#    Долгота: 37.673477
#    Телефон: 8 (964) 791-44-26
#    Сайт: http://chertabar.ru
#    Instagram: chertabar
#    Гео-кластер: 34
#
# 98. Pâté & Co
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Балчуг, 3/2
#    Широта: 55.747675
#    Долгота: 37.625656
#    Телефон: 8 (495) 252-07-06
#    Сайт: http://www.patecafe.ru
#    Instagram: pate_brasserie
#    Гео-кластер: 40
#
# 99. Устричная и Шампанский бар
#    Тип: Restaurant
#    Score: 34
#    Адрес: ул. Варварка 6 ст3
#    Широта: 55.750412
#    Долгота: 37.628453
#    Телефон: 8 (495) 531-09-50
#    Сайт: http://zaryadyegastrocenter.ru
#    Instagram: zaryadye_gastrocenter
#    Гео-кластер: 40
#
# 100. Просто Вкусно Пироги
#    Тип: Restaurant
#    Score: 34
#    Адрес: Мира проспект 150
#    Широта: 55.822317
#    Долгота: 37.647192
#    Телефон: 8 (495) 120-50-12
#    Сайт: https://pirogi.love
#    Instagram: prostovkusnopirogi
#    Гео-кластер: 49
#
# === СВОДНАЯ ИНФОРМАЦИЯ ===
# Сохранено 100 заведений в 'top_100_moscow_restaurants_with_coordinates.csv'
# Распределение по типам:
# type
# Restaurant    93
# Bar            7
# Name: count, dtype: int64
# Диапазон score: 34 - 44
# Диапазон широт: 55.629368 - 55.967140
# Диапазон долгот: 37.405527 - 37.802930
#
# === ГЕОГРАФИЧЕСКАЯ СТАТИСТИКА ===
# Средняя широта: 55.761002
# Средняя долгота: 37.588405
# Уникальных гео-кластеров в топ-100: 15

# %%
# Сохраняем топ-100 заведений со всей информацией
df_top_100 = df_top_1500.nlargest(100, 'score').copy()

# Выбираем нужные колонки включая широту и долготу
df_top_100[['fsq_place_id', 'name', 'address', 'latitude', 'longitude',
           'tel', 'website', 'instagram', 'type', 'score', 'geo_cluster']].to_csv(
    'moscow_top_100_restaurants.csv', index=False, encoding='utf-8')

print("Сохранено 100 заведений в moscow_top_100_restaurants.csv")
print(f"Файл содержит: широту, долготу, адреса, контакты и scoring")
# Out:
# Сохранено 100 заведений в moscow_top_100_restaurants.csv
# Файл содержит: широту, долготу, адреса, контакты и scoring
